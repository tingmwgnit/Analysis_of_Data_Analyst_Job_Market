# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('C:/Users/Ting/OneDrive/Desktop/data_analyst_project/DataAnalyst_Cleaned.csv')

# %%
df.head()
# Out:
#                                            Job Title  \
# 0  Data Analyst, Center on Immigration and Justic...
# 1                               Quality Data Analyst
# 2  Senior Data Analyst, Insights & Analytics Team...
# 3                                       Data Analyst
# 4                             Reporting Data Analyst
#
#               Salary Estimate  \
# 0  $37K-$66K (Glassdoor est.)
# 1  $37K-$66K (Glassdoor est.)
# 2  $37K-$66K (Glassdoor est.)
# 3  $37K-$66K (Glassdoor est.)
# 4  $37K-$66K (Glassdoor est.)
#
#                                      Job Description  Rating  \
# 0  Are you eager to roll up your sleeves and harn...     3.2
# 1  Overview\n\nProvides analytical and technical ...     3.8
# 2  We’re looking for a Senior Data Analyst who ha...     3.4
# 3  Requisition NumberRR-0001939\nRemote:Yes\nWe c...     4.1
# 4  ABOUT FANDUEL GROUP\n\nFanDuel Group is a worl...     3.9
#
#                               Company Name      Location  Headquarters  \
# ...

# %%
df.columns
# Out:
# Index(['Job Title', 'Salary Estimate', 'Job Description', 'Rating',
#        'Company Name', 'Location', 'Headquarters', 'Size', 'Founded',
#        'Type of ownership', 'Industry', 'Sector', 'Revenue', 'Competitors',
#        'Easy Apply', 'Min_Salary', 'Max_Salary', 'Ave_Salary',
#        'Company_Name_Text', 'State', 'Headquarter_Position', 'Company_age',
#        'Python', 'R_Studio', 'SQL', 'Excel', 'Machine_Learning', 'Tableau',
#        'AWS', 'Spark', 'Google_Analytics', 'Power_BI', 'Big_Query', 'Looker',
#        'Job_Simp', 'Seniority', 'Num_Comp'],
#       dtype='object')

# %%
df.describe() #all continues variables
# Out:
#             Rating      Founded   Min_Salary   Max_Salary   Ave_Salary  \
# count  2251.000000  2251.000000  2251.000000  2251.000000  2251.000000
# mean      3.161928  1398.876944    54.267437    89.975122    72.121279
# std       1.663451   901.758003    19.579706    29.321502    23.605836
# min      -1.000000    -1.000000    24.000000    38.000000    33.500000
# 25%       3.100000    -1.000000    41.000000    70.000000    58.000000
# 50%       3.600000  1979.000000    50.000000    87.000000    69.000000
# 75%       4.000000  2002.000000    64.000000   104.000000    80.500000
# max       5.000000  2019.000000   113.000000   190.000000   150.000000
#
#        Headquarter_Position  Company_age       Python     R_Studio  \
# count           2251.000000  2251.000000  2251.000000  2251.000000
# mean               0.289205    29.872057     0.282985     0.005331
# std                0.453494    44.862353     0.450549     0.072835
# ...

# %%
df.Rating.hist()
# Out:
# <AxesSubplot:>

# %%
df.boxplot(column = ['Rating'])
# Out:
# <AxesSubplot:>

# %%
df.Ave_Salary.hist()
# Out:
# <AxesSubplot:>

# %%
df.boxplot(column = ['Ave_Salary'])
# Out:
# <AxesSubplot:>

# %%
df.Company_age.hist()
# Out:
# <AxesSubplot:>

# %%
df.boxplot(column = ['Company_age'])
# Out:
# <AxesSubplot:>

# %%
df[['Company_age','Ave_Salary','Rating','Num_Comp']].corr()   #correlation of continues variables(numeric factors)
# Out:
#              Company_age  Ave_Salary    Rating  Num_Comp
# Company_age     1.000000   -0.075545  0.188142  0.299648
# Ave_Salary     -0.075545    1.000000  0.004489  0.002272
# Rating          0.188142    0.004489  1.000000  0.166113
# Num_Comp        0.299648    0.002272  0.166113  1.000000

# %%
#map the correlation
cmap = sns.diverging_palette(150, 275, as_cmap=True)
sns.heatmap(df[['Company_age','Ave_Salary','Rating','Num_Comp']].corr(), vmax=.5, center=0, cmap=cmap,
            square=True, linewidths=.5, cbar_kws={"shrink": .5})
# Out:
# <AxesSubplot:>

# %%
#numeric factors & characteristic factors
df_num = df[['Company_age','Ave_Salary','Rating','Num_Comp']]
df_cat = df[['Location', 'Headquarters', 'Size', 'Type of ownership', 'Industry', 'Sector', 'Revenue','Company_Name_Text', 'State', 'Headquarter_Position', 'Python', 'R_Studio', 'SQL', 'Excel', 'Machine_Learning', 'Tableau',
       'AWS', 'Spark', 'Google_Analytics', 'Power_BI', 'Big_Query', 'Looker',
       'Job_Simp', 'Seniority']]

# %%
for i in df_cat.columns:
    cat_num = df_cat[i].value_counts()
    print("graph for %s: total = %d" % (i, len(cat_num)))
    chart = sns.barplot(x=cat_num.index, y=cat_num)
    chart.set_xticklabels(chart.get_xticklabels(), rotation=90)
    plt.show()
# Out:
# graph for Location: total = 253
# graph for Headquarters: total = 483
# graph for Size: total = 9
# graph for Type of ownership: total = 15
# graph for Industry: total = 89
# graph for Sector: total = 25
# graph for Revenue: total = 14
# graph for Company_Name_Text: total = 1501
# graph for State: total = 19
# graph for Headquarter_Position: total = 2
# graph for Python: total = 2
# graph for R_Studio: total = 2
# graph for SQL: total = 2
# graph for Excel: total = 2
# graph for Machine_Learning: total = 2
# graph for Tableau: total = 2
# graph for AWS: total = 2
# graph for Spark: total = 2
# graph for Google_Analytics: total = 2
# graph for Power_BI: total = 2
# graph for Big_Query: total = 2
# graph for Looker: total = 2
# graph for Job_Simp: total = 3
# graph for Seniority: total = 3

# %%
for i in df_cat[['Location','Headquarters','Company_Name_Text']].columns:
    cat_num = df_cat[i].value_counts()[:20]
    print("graph for %s: total = %d" % (i, len(cat_num)))
    chart = sns.barplot(x=cat_num.index, y=cat_num)
    chart.set_xticklabels(chart.get_xticklabels(), rotation=90)
    plt.show()
# Out:
# graph for Location: total = 20
# graph for Headquarters: total = 20
# graph for Company_Name_Text: total = 20

# %%
pd.pivot_table(df, index = 'Job_Simp', values = 'Ave_Salary')
# Out:
#                 Ave_Salary
# Job_Simp
# analyst          72.168468
# data engineer    67.058824
# data scientist   70.785714

# %%
pd.pivot_table(df, index = ['Job_Simp','Seniority'], values = 'Ave_Salary')
# Out:
#                           Ave_Salary
# Job_Simp       Seniority
# analyst        jr          63.423077
#                na          71.570029
#                senior      74.609110
# data engineer  na          68.076923
#                senior      63.750000
# data scientist na          63.166667
#                senior      84.500000

# %%
pd.pivot_table(df, index = ['State','Job_Simp'], values = 'Ave_Salary', aggfunc = 'count').sort_values('State', ascending = False)
# Out:
#                       Ave_Salary
# State Job_Simp
#  WA   analyst                 53
#  VA   analyst                 48
#  UT   data scientist           1
#       data engineer            3
#       analyst                 29
#  TX   data engineer            3
#       analyst                388
#       data scientist           3
#  SC   analyst                  3
#  PA   data engineer            1
#       analyst                113
#  OH   data scientist           2
#       analyst                 33
#  NY   data scientist           2
#       data engineer            1
#       analyst                342
#  NJ   data scientist           1
#       analyst                 85
#  NC   analyst                 88
#       data engineer            1
#  KS   analyst                  3
#  IN   analyst                 23
#  IL   data scientist           2
#       data engineer            2
#       analyst                160
#  GA   analyst                  4
#  FL   analyst                 27
# ...

# %%
pd.pivot_table(df[df.Job_Simp == 'analyst'], index = 'State', values = 'Ave_Salary').sort_values('Ave_Salary', ascending = False)
# Out:
#        Ave_Salary
# State
#  CA     88.362682
#  IL     78.109375
#  CO     73.542105
#  NJ     73.076471
#  NY     71.422515
#  AZ     70.812500
#  SC     68.333333
#  NC     68.022727
#  VA     65.187500
#  WA     64.754717
#  PA     61.491150
#  DE     59.727273
#  TX     58.820876
#  FL     51.851852
#  KS     51.500000
#  IN     47.500000
#  OH     45.515152
#  GA     44.000000
#  UT     37.672414

# %%
pd.pivot_table(df[df.Job_Simp == 'analyst'], index = 'State', values = 'Ave_Salary', aggfunc = 'count').sort_values('Ave_Salary', ascending = False)
# Out:
#        Ave_Salary
# State
#  CA           619
#  TX           388
#  NY           342
#  IL           160
#  PA           113
#  AZ            96
#  CO            95
#  NC            88
#  NJ            85
#  WA            53
#  VA            48
#  OH            33
#  UT            29
#  FL            27
#  IN            23
#  DE            11
#  GA             4
#  KS             3
#  SC             3

# %%
df_pivots = df[['Rating', 'Industry', 'Sector', 'Revenue', 'Num_Comp', 'Python', 'R_Studio', 'Spark', 'AWS', 'Excel', 'Type of ownership','Ave_Salary']]

# %%
for i in df_pivots.columns:
    print(i)
    print(pd.pivot_table(df_pivots,index =i, values = 'Ave_Salary').sort_values('Ave_Salary', ascending = False))
#even though there is error reported, but we got what we want
# Out:
# Rating
#         Ave_Salary
# Rating
#  2.2     95.666667
#  4.4     82.366667
#  1.7     82.000000
#  1.6     80.000000
#  2.0     79.750000
#  2.4     77.350000
#  4.5     76.925532
#  3.2     76.901099
#  2.1     76.625000
#  4.0     76.232558
#  3.9     75.210714
#  4.6     74.760870
#  4.1     74.424370
#  2.3     73.888889
#  4.2     73.159574
#  4.8     72.913793
# -1.0     72.856089
#  2.5     72.781250
#  3.4     72.158416
#  5.0     72.125954
#  3.7     71.803030
#  3.3     71.440367
#  4.7     71.000000
#  3.0     70.982456
#  3.8     69.534615
#  3.6     69.207407
#  3.1     68.801471
#  4.3     68.172727
#  2.8     67.825581
#  3.5     67.240000
#  2.9     66.887500
#  2.6     65.821429
#  1.0     64.250000
#  2.7     62.780000
#  4.9     61.470588
#  1.9     61.250000
#  1.8     58.250000
# Industry
#                                            Ave_Salary
# Industry
# Drug & Health Stores                        95.250000
# ...

# %%
pd.pivot_table(df_pivots, index = 'Revenue', columns = 'Python', values = 'Ave_Salary', aggfunc = 'count')
# Out:
# Python                              0    1
# Revenue
# $1 to $2 billion (USD)             65   22
# $1 to $5 million (USD)             82   29
# $10 to $25 million (USD)           94   38
# $10+ billion (USD)                133   56
# $100 to $500 million (USD)        158   60
# $2 to $5 billion (USD)             97   32
# $25 to $50 million (USD)           76   33
# $5 to $10 billion (USD)            36   20
# $5 to $10 million (USD)            57   15
# $50 to $100 million (USD)         168   31
# $500 million to $1 billion (USD)   61   18
# -1                                126   36
# Less than $1 million (USD)         73   20
# Unknown / Non-Applicable          388  227

# %%
from wordcloud import WordCloud, ImageColorGenerator, STOPWORDS
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
